# %% [markdown]
# # Example : Show Result Triplets

# %%
import pandas as pd

df = pd.read_csv('preprocessed/sankey_course_mapping.csv')
df
# Out:
#                        source  \
# 0            Travel Company 1
# 1            Travel Company 1
# 2            Travel Company 1
# 3            Travel Company 1
# 4            Travel Company 1
# ..                        ...
# 294  Tech/Software Company 12
# 295  Tech/Software Company 12
# 296  Tech/Software Company 12
# 297  Tech/Software Company 12
# 298  Tech/Software Company 12
#
#                                                 target  value
# 0          CN101: Introduction to Computer Programming      1
# 1                              CN230: Database Systems      1
# 2                             CN311: Operating Systems      1
# 3    CN321: Data Communication and Computer Networks I      1
# 4                   SF211: Object-oriented programming      1
# ..                                                 ...    ...
# 294    SF222: Software Engineering Models and Analysis      1
# 295            SF331: Software Architecture and Design      1
# ...
